# %%
from google.colab import userdata
passkey = userdata.get('GOOGLE_API_KEY')

# %%
import google.generativeai as genai
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)

# %%
genai.configure(api_key=passkey)

# %%
for model in genai.list_models():
  print(model.name)
# Out:
# models/embedding-gecko-001
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-exp-1206
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-preview-09-2025
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/deep-research-pro-preview-12-2025
# models/embedding-001
# models/text-embedding-004
# models/gemini-embedding-exp-03-07
# models/gemini-embedding-exp
# models/gemini-embedding-001
# models/aqa
# models/imagen-4.0-generate-preview-06-06
# models/imagen-4.0-ultra-generate-preview-06-06
# models/imagen-4.0-generate-001
# models/imagen-4.0-ultra-generate-001
# models/imagen-4.0-fast-generate-001
# models/veo-2.0-generate-001
# models/veo-3.0-generate-001
# models/veo-3.0-fast-generate-001
# models/veo-3.1-generate-preview
# models/veo-3.1-fast-generate-preview
# models/gemini-2.5-flash-native-audio-latest
# models/gemini-2.5-flash-native-audio-preview-09-2025
# models/gemini-2.5-flash-native-audio-preview-12-2025

# %%
model =genai.GenerativeModel("gemini-2.5-flash")
respond =model.generate_content("whats todyaas date")
# Out:
# /tmp/ipython-input-2609779457.py:2: RuntimeWarning: coroutine 'GenerativeModel.generate_content_async' was never awaited
#   respond =model.generate_content("whats todyaas date")
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
print(respond.text)
# Out:
# Today's date is **Thursday, May 23, 2024**.

# %%
from PIL import Image
img=Image.open('/content/imge.jpg')

response=model.generate_content(img)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=894x493>

# %%
print(response.text)
# Out:
# This image is a vibrant and abstract painting, strongly influenced by Cubism and perhaps Expressionism, featuring a dynamic composition of stylized figures and geometric shapes.
#
# Here's a detailed description:
#
# **Composition and Figures:**
# The painting is horizontally oriented and depicts three prominent, abstract figures, resembling heads or busts, arranged in a row from left to right. They are rendered with bold black outlines, giving them a distinct, almost stained-glass or cloisonné appearance.
#
# 1.  **Left Figure:** This figure has an elongated, somewhat angular profile, with a dominant orange and white color scheme for the "face" area. Its "eye" is a dark, almond shape. A striking detail near the base of this figure is a pair of green, bird-like creatures – one larger and seemingly sheltering a smaller one – which adds a touch of naturalistic symbolism amidst the abstraction.
# 2.  **Middle Figure:** Positioned centrally, this figure has a more frontal, mask-like appearance with closed or downward-gazing eyes. Its face is broadly divided, with one side in a rich orange and the other in a vibrant green, separated by a prominent white/cream area that forms part of the nose/forehead.
# 3.  **Right Figure:** This figure, like the left one, is primarily orange with an elongated dark eye. It appears slightly simpler in form than the other two, contributing to the visual rhythm across the canvas.
#
# **Color Palette:**
# The artwork bursts with a rich and contrasting color palette. Dominant hues include various shades of orange, red, deep blues, vibrant greens, sunny yellows, and crisp white/cream. These colors are applied in large, flat areas, often with subtle textural variations visible, suggesting paint on canvas. The black outlines serve to delineate forms and intensify the contrast between colors.
#
# **Background and Style:**
# The background is equally abstract, composed of a mosaic of angular and curvilinear shapes filled with the same bright colors as the figures. These geometric patterns often overlap or interlock, creating a sense of depth and movement. The overall style suggests a modern abstract aesthetic, drawing inspiration from early 20th-century art movements like Cubism for its fragmented forms and multiple perspectives, and possibly Expressionism for its bold colors and emotional intensity. There's also a noticeable influence of tribal or African mask art in the stylized facial features.
#
# **Overall Impression:**
# The painting is visually engaging and energetic. It evokes themes of human connection, contemplation, or perhaps a stylized family group, given the figures' arrangement and the symbolic birds on the left. Its vibrant colors and strong graphic quality make it a compelling piece of modern art.
